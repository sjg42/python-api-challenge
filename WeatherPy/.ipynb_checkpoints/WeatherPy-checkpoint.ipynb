of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 5 | mehamn
# Processing Record 7 of Set 5 | barranca
# Processing Record 8 of Set 5 | jawhar
# Processing Record 9 of Set 5 | staraya russa
# Processing Record 10 of Set 5 | saint-georges
# Processing Record 11 of Set 5 | curup
# Processing Record 12 of Set 5 | nanortalik
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | vardo
# Processing Record 15 of Set 5 | rio grande
# Processing Record 16 of Set 5 | wucheng
# Processing Record 17 of Set 5 | santa rosa
# Processing Record 18 of Set 5 | tura
# Processing Record 19 of Set 5 | pozo colorado
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | katsuura
# Processing Record 22 of Set 5 | vanimo
# Processing Record 23 of Set 5 | longyearbyen
# Processing Record 24 of Set 5 | vilyuysk
# Processing Record 25 of Set 5 | yamada
# Processing Record 26 of Set 5 | kijang
# Processing Record 27 of Set 5 | itaituba
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | port hardy
# Processing Record 30 of Set 5 | biak
# Processing Record 31 of Set 5 | san ignacio
# Processing Record 32 of Set 5 | ormara
# Processing Record 33 of Set 5 | kambove
# Processing Record 34 of Set 5 | picota
# Processing Record 35 of Set 5 | general roca
# Processing Record 36 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 5 | the valley
# Processing Record 38 of Set 5 | nikolskoye
# Processing Record 39 of Set 5 | hualmay
# Processing Record 40 of Set 5 | oksfjord
# Processing Record 41 of Set 5 | rio gallegos
# Processing Record 42 of Set 5 | alghero
# Processing Record 43 of Set 5 | asau
# Processing Record 44 of Set 5 | key west
# Processing Record 45 of Set 5 | mapiripan
# Processing Record 46 of Set 5 | pitimbu
# Processing Record 47 of Set 5 | nizwa
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | hobyo
# Processing Record 0 of Set 6 | namatanai
# Processing Record 1 of Set 6 | ipixuna
# Processing Record 2 of Set 6 | mumford
# Processing Record 3 of Set 6 | san policarpo
# Processing Record 4 of Set 6 | pindi gheb
# Processing Record 5 of Set 6 | moose factory
# Processing Record 6 of Set 6 | torbay
# Processing Record 7 of Set 6 | jibuti
# Processing Record 8 of Set 6 | jennings
# Processing Record 9 of Set 6 | dedovichi
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | dosso
# Processing Record 12 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 13 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 6 | oxelosund
# Processing Record 15 of Set 6 | puerto ayora
# Processing Record 16 of Set 6 | neftcala
# Processing Record 17 of Set 6 | naze
# Processing Record 18 of Set 6 | paamiut
# Processing Record 19 of Set 6 | erenhot
# Processing Record 20 of Set 6 | townsville
# Processing Record 21 of Set 6 | lavrentiya
# Processing Record 22 of Set 6 | bubaque
# Processing Record 23 of Set 6 | mana
# Processing Record 24 of Set 6 | lewisporte
# Processing Record 25 of Set 6 | glenwood springs
# Processing Record 26 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 6 | aykhal
# Processing Record 28 of Set 6 | beloha
# Processing Record 29 of Set 6 | ust-kut
# Processing Record 30 of Set 6 | oktyabrskiy
# Processing Record 31 of Set 6 | tilichiki
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | ust-koksa
# Processing Record 34 of Set 6 | wuwei
# Processing Record 35 of Set 6 | maarianhamina
# Processing Record 36 of Set 6 | savannah bight
# Processing Record 37 of Set 6 | gat
# Processing Record 38 of Set 6 | yeniseysk
# Processing Record 39 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 40 of Set 6 | mubarakpur
# Processing Record 41 of Set 6 | minab
# Processing Record 42 of Set 6 | sumenep
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | saint-ambroise
# Processing Record 45 of Set 6 | sola
# Processing Record 46 of Set 6 | carutapera
# Processing Record 47 of Set 6 | baykit
# Processing Record 48 of Set 6 | isangel
# Processing Record 49 of Set 6 | finschhafen
# Processing Record 0 of Set 7 | saldanha
# Processing Record 1 of Set 7 | kawasaki
# Processing Record 2 of Set 7 | salinas
# Processing Record 3 of Set 7 | coquimbo
# Processing Record 4 of Set 7 | sao filipe
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | havoysund
# Processing Record 7 of Set 7 | sechura
# Processing Record 8 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 7 | westport
# Processing Record 10 of Set 7 | twin falls
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | fukue
# Processing Record 14 of Set 7 | husavik
# Processing Record 15 of Set 7 | presov
# Processing Record 16 of Set 7 | el alto
# Processing Record 17 of Set 7 | carnarvon
# Processing Record 18 of Set 7 | vuktyl
# Processing Record 19 of Set 7 | maningrida
# Processing Record 20 of Set 7 | krasnoselkup
# Processing Record 21 of Set 7 | zolotukhino
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | broken hill
# Processing Record 25 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 7 | rawson
# Processing Record 28 of Set 7 | bandarbeyla
# Processing Record 29 of Set 7 | college
# Processing Record 30 of Set 7 | launceston
# Processing Record 31 of Set 7 | san quintin
# Processing Record 32 of Set 7 | kalevala
# Processing Record 33 of Set 7 | pointe michel
# Processing Record 34 of Set 7 | salaga
# Processing Record 35 of Set 7 | zyukayka
# Processing Record 36 of Set 7 | miracema do tocantins
# Processing Record 37 of Set 7 | surt
# Processing Record 38 of Set 7 | yar-sale
# Processing Record 39 of Set 7 | loikaw
# Processing Record 40 of Set 7 | srednekolymsk
# Processing Record 41 of Set 7 | leiyang
# Processing Record 42 of Set 7 | osypenko
# Processing Record 43 of Set 7 | shaunavon
# Processing Record 44 of Set 7 | abha
# Processing Record 45 of Set 7 | dauphin
# Processing Record 46 of Set 7 | hasaki
# Processing Record 47 of Set 7 | bud
# Processing Record 48 of Set 7 | marawi
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 0 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 8 | maua
# Processing Record 2 of Set 8 | wasilla
# Processing Record 3 of Set 8 | charters towers
# Processing Record 4 of Set 8 | ucluelet
# Processing Record 5 of Set 8 | olinda
# Processing Record 6 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 8 | galveston
# Processing Record 8 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 8 | bethlehem
# Processing Record 11 of Set 8 | churapcha
# Processing Record 12 of Set 8 | cacapava do sul
# Processing Record 13 of Set 8 | asyut
# Processing Record 14 of Set 8 | emerald
# Processing Record 15 of Set 8 | cullman
# Processing Record 16 of Set 8 | kutum
# Processing Record 17 of Set 8 | jalu
# Processing Record 18 of Set 8 | tigil
# Processing Record 19 of Set 8 | sitka
# Processing Record 20 of Set 8 | birin
# Processing Record 21 of Set 8 | riyadh
# Processing Record 22 of Set 8 | dunedin
# Processing Record 23 of Set 8 | florianopolis
# Processing Record 24 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 8 | sao joao da barra
# Processing Record 26 of Set 8 | necochea
# Processing Record 27 of Set 8 | washington
# Processing Record 28 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 8 | karratha
# Processing Record 30 of Set 8 | farafangana
# Processing Record 31 of Set 8 | khasan
# Processing Record 32 of Set 8 | bukachacha
# Processing Record 33 of Set 8 | general pico
# Processing Record 34 of Set 8 | timmins
# Processing Record 35 of Set 8 | raudeberg
# Processing Record 36 of Set 8 | princeton
# Processing Record 37 of Set 8 | padang
# Processing Record 38 of Set 8 | berdigestyakh
# Processing Record 39 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 40 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 8 | saint-augustin
# Processing Record 42 of Set 8 | aklavik
# Processing Record 43 of Set 8 | evensk
# Processing Record 44 of Set 8 | podgorica
# Processing Record 45 of Set 8 | coulihaut
# City not found. Skipping...
# Processing Record 46 of Set 8 | touros
# Processing Record 47 of Set 8 | qesarya
# Processing Record 48 of Set 8 | zheleznodorozhnyy
# Processing Record 49 of Set 8 | challans
# Processing Record 0 of Set 9 | hofn
# Processing Record 1 of Set 9 | ankara
# Processing Record 2 of Set 9 | kurayoshi
# Processing Record 3 of Set 9 | iqaluit
# Processing Record 4 of Set 9 | arki
# Processing Record 5 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 6 of Set 9 | camargo
# Processing Record 7 of Set 9 | hambantota
# Processing Record 8 of Set 9 | la ronge
# Processing Record 9 of Set 9 | cotonou
# Processing Record 10 of Set 9 | broome
# Processing Record 11 of Set 9 | pervomayskiy
# Processing Record 12 of Set 9 | polunochnoye
# Processing Record 13 of Set 9 | gavle
# Processing Record 14 of Set 9 | alta floresta
# Processing Record 15 of Set 9 | muroto
# Processing Record 16 of Set 9 | cilegon
# Processing Record 17 of Set 9 | los andes
# Processing Record 18 of Set 9 | salalah
# Processing Record 19 of Set 9 | yaan
# Processing Record 20 of Set 9 | baglung
# Processing Record 21 of Set 9 | faya
# Processing Record 22 of Set 9 | araouane
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | conde
# Processing Record 25 of Set 9 | beringovskiy
# Processing Record 26 of Set 9 | egvekinot
# Processing Record 27 of Set 9 | nizhniy kuranakh
# Processing Record 28 of Set 9 | beaver dam
# Processing Record 29 of Set 9 | chirongui
# Processing Record 30 of Set 9 | vao
# Processing Record 31 of Set 9 | felsberg
# Processing Record 32 of Set 9 | bukama
# Processing Record 33 of Set 9 | kindu
# Processing Record 34 of Set 9 | bichura
# Processing Record 35 of Set 9 | benton harbor
# Processing Record 36 of Set 9 | nishihara
# Processing Record 37 of Set 9 | san-pedro
# Processing Record 38 of Set 9 | dedougou
# Processing Record 39 of Set 9 | nanning
# Processing Record 40 of Set 9 | ionia
# Processing Record 41 of Set 9 | zhob
# Processing Record 42 of Set 9 | omsukchan
# Processing Record 43 of Set 9 | ayolas
# Processing Record 44 of Set 9 | moratuwa
# Processing Record 45 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 46 of Set 9 | kribi
# Processing Record 47 of Set 9 | fare
# Processing Record 48 of Set 9 | adre
# Processing Record 49 of Set 9 | stromness
# Processing Record 0 of Set 10 | tommot
# Processing Record 1 of Set 10 | nome
# Processing Record 2 of Set 10 | mazagao
# Processing Record 3 of Set 10 | fairbanks
# Processing Record 4 of Set 10 | progreso
# Processing Record 5 of Set 10 | qaqortoq
# Processing Record 6 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 10 | islahiye
# Processing Record 8 of Set 10 | motygino
# Processing Record 9 of Set 10 | fergus falls
# Processing Record 10 of Set 10 | tessalit
# Processing Record 11 of Set 10 | san buenaventura
# Processing Record 12 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 10 | cockburn town
# Processing Record 14 of Set 10 | bagan
# Processing Record 15 of Set 10 | bonavista
# Processing Record 16 of Set 10 | puri
# Processing Record 17 of Set 10 | pingxiang
# Processing Record 18 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 10 | archidona
# Processing Record 20 of Set 10 | los llanos de aridane
# Processing Record 21 of Set 10 | diadi
# Processing Record 22 of Set 10 | russell
# Processing Record 23 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 10 | yambio
# Processing Record 25 of Set 10 | vila
# Processing Record 26 of Set 10 | erzin
# Processing Record 27 of Set 10 | nioro
# Processing Record 28 of Set 10 | candido mendes
# Processing Record 29 of Set 10 | ivanovka
# Processing Record 30 of Set 10 | gamba
# Processing Record 31 of Set 10 | korla
# Processing Record 32 of Set 10 | pedernales
# Processing Record 33 of Set 10 | victoria
# Processing Record 34 of Set 10 | cayenne
# Processing Record 35 of Set 10 | madingou
# Processing Record 36 of Set 10 | fort nelson
# Processing Record 37 of Set 10 | delijan
# Processing Record 38 of Set 10 | tampere
# Processing Record 39 of Set 10 | valentin gomez farias
# Processing Record 40 of Set 10 | palaiokhora
# City not found. Skipping...
# Processing Record 41 of Set 10 | morristown
# Processing Record 42 of Set 10 | akhisar
# Processing Record 43 of Set 10 | pemangkat
# Processing Record 44 of Set 10 | paita
# Processing Record 45 of Set 10 | tarsus
# Processing Record 46 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 10 | shingu
# Processing Record 48 of Set 10 | maniitsoq
# Processing Record 49 of Set 10 | shimoda
# Processing Record 0 of Set 11 | porterville
# Processing Record 1 of Set 11 | zhanaozen
# Processing Record 2 of Set 11 | pringsewu
# Processing Record 3 of Set 11 | umaria
# Processing Record 4 of Set 11 | kaniama
# Processing Record 5 of Set 11 | brajrajnagar
# City not found. Skipping...
# Processing Record 6 of Set 11 | morehead
# Processing Record 7 of Set 11 | faro
# Processing Record 8 of Set 11 | aksarayskiy
# Processing Record 9 of Set 11 | george town
# Processing Record 10 of Set 11 | sao jose da coroa grande
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | tukrah
# Processing Record 13 of Set 11 | flinders
# Processing Record 14 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 15 of Set 11 | bol
# Processing Record 16 of Set 11 | luderitz
# Processing Record 17 of Set 11 | tucuma
# Processing Record 18 of Set 11 | la rioja
# Processing Record 19 of Set 11 | rennes
# Processing Record 20 of Set 11 | saint-pacome
# City not found. Skipping...
# Processing Record 21 of Set 11 | margate
# Processing Record 22 of Set 11 | ciro marina
# Processing Record 23 of Set 11 | acurenam
# Processing Record 24 of Set 11 | miramar
# Processing Record 25 of Set 11 | dhidhdhoo
# Processing Record 26 of Set 11 | krasnovishersk
# Processing Record 27 of Set 11 | ambilobe
# Processing Record 28 of Set 11 | konin
# Processing Record 29 of Set 11 | bianzhuang
# Processing Record 30 of Set 11 | yulara
# Processing Record 31 of Set 11 | kysyl-syr
# Processing Record 32 of Set 11 | lahaina
# Processing Record 33 of Set 11 | inhambane
# Processing Record 34 of Set 11 | walvis bay
# Processing Record 35 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 11 | mananara
# Processing Record 39 of Set 11 | san antonio
# Processing Record 40 of Set 11 | axim
# Processing Record 41 of Set 11 | divnogorsk
# Processing Record 42 of Set 11 | uribia
# Processing Record 43 of Set 11 | ugoofaaru
# Processing Record 44 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 11 | riachao
# Processing Record 46 of Set 11 | vicuna
# Processing Record 47 of Set 11 | ndungu
# Processing Record 48 of Set 11 | tavda
# Processing Record 49 of Set 11 | matara
# Processing Record 0 of Set 12 | komsomolskiy
# Processing Record 1 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 12 | khorixas
# Processing Record 3 of Set 12 | maracacume
# Processing Record 4 of Set 12 | saint-pierre
# Processing Record 5 of Set 12 | mahanoro
# Processing Record 6 of Set 12 | tibirita
# Processing Record 7 of Set 12 | putyatino
# Processing Record 8 of Set 12 | grindavik
# Processing Record 9 of Set 12 | altamont
# Processing Record 10 of Set 12 | clyde river
# Processing Record 11 of Set 12 | benguela
# Processing Record 12 of Set 12 | luanda
# Processing Record 13 of Set 12 | chanhassen
# Processing Record 14 of Set 12 | hamilton
# Processing Record 15 of Set 12 | deputatskiy
# Processing Record 16 of Set 12 | namtsy
# Processing Record 17 of Set 12 | monrovia
# Processing Record 18 of Set 12 | consolacion del sur
# Processing Record 19 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 20 of Set 12 | thompson
# Processing Record 21 of Set 12 | svetlogorsk
# Processing Record 22 of Set 12 | bathsheba
# Processing Record 23 of Set 12 | bourail
# Processing Record 24 of Set 12 | andenes
# Processing Record 25 of Set 12 | bogorodskoye
# Processing Record 26 of Set 12 | turki
# Processing Record 27 of Set 12 | buala
# Processing Record 28 of Set 12 | saint-leu
# Processing Record 29 of Set 12 | panzos
# Processing Record 30 of Set 12 | goure
# Processing Record 31 of Set 12 | ponta delgada
# Processing Record 32 of Set 12 | hecun
# Processing Record 33 of Set 12 | berlevag
# Processing Record 34 of Set 12 | iskateley
# Processing Record 35 of Set 12 | huarmey
# Processing Record 36 of Set 12 | mount gambier
# Processing Record 37 of Set 12 | kamaishi
# Processing Record 38 of Set 12 | brae
# Processing Record 39 of Set 12 | kavaratti
# Processing Record 40 of Set 12 | jodar
# Processing Record 41 of Set 12 | formosa do rio preto
# Processing Record 42 of Set 12 | vila velha
# Processing Record 43 of Set 12 | tonneins
# Processing Record 44 of Set 12 | sabang
# Processing Record 45 of Set 12 | lerwick
# Processing Record 46 of Set 12 | zabol
# Processing Record 47 of Set 12 | rafaela
# Processing Record 48 of Set 12 | port macquarie
# Processing Record 49 of Set 12 | pimentel
# Processing Record 0 of Set 13 | port hawkesbury
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) #city_data already is 
                                    #a list of dictionaries!

# Show Record Count
city_data_df.count()
# Out:
# City          445
# Lat           445
# Lng           445
# Max Temp      445
# Humidity      445
# Cloudiness    445
# Wind Speed    445
# Country       445
# Date          445
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# 0                      kandrian  -6.2167  149.5500     81.37        79
# 1                ribeira grande  38.5167  -28.7000     54.77        85
# 2  sao raimundo das mangabeiras  -7.0219  -45.4811     76.78        80
# 3                    kaitangata -46.2817  169.8464     59.76        47
# 4                    wilmington  34.2257  -77.9447     75.11        64
#
#    Cloudiness  Wind Speed Country        Date
# 0          99        6.04      PG  1677886981
# 1          95        3.00      PT  1677886427
# 2          26        3.80      BR  1677886983
# 3          92        6.55      NZ  1677886984
# 4           0       23.02      US  1677886954

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                  City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                            kandrian  -6.2167  149.5500     81.37        79
# 1                      ribeira grande  38.5167  -28.7000     54.77        85
# 2        sao raimundo das mangabeiras  -7.0219  -45.4811     76.78        80
# 3                          kaitangata -46.2817  169.8464     59.76        47
# 4                          wilmington  34.2257  -77.9447     75.11        64
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99        6.04      PG  1677886981
# 1                95        3.00      PT  1677886427
# 2                26        3.80      BR  1677886983
# 3                92        6.55      NZ  1677886984
# 4                 0       23.02      US  1677886954

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (2023-03-03)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-03-03)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-03-03)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2023-03-03)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def LinReg(slope,intercept,r, x_data):
    print(f"The r-value is: {r}")
    xs = range(int(min(x_data)),int(max(x_data)))
    ys = slope*xs + intercept
    plt.plot(xs,ys,'r-')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        ribeira grande  38.5167  -28.7000     54.77        85          95
# 4            wilmington  34.2257  -77.9447     75.11        64           0
# 5            georgetown   5.4112  100.3354     76.93        94          20
# 6        severo-kurilsk  50.6789  156.1250     21.79        69          99
# 7          norman wells  65.2820 -126.8329     -9.36        64          20
#
#          Wind Speed Country        Date
# City_ID
# 1              3.00      PT  1677886427
# 4             23.02      US  1677886954
# 5              2.30      MY  1677886920
# 6             21.88      RU  1677886987
# 7             13.80      CA  1677886989

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                  City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                            kandrian  -6.2167  149.5500     81.37        79
# 2        sao raimundo das mangabeiras  -7.0219  -45.4811     76.78        80
# 3                          kaitangata -46.2817  169.8464     59.76        47
# 8                           cape town -33.9258   18.4232     67.91        85
# 10                              ambon  -3.6954  128.1814     80.74        14
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                99        6.04      PG  1677886981
# 2                26        3.80      BR  1677886983
# 3                92        6.55      NZ  1677886984
# 8                20       10.36      ZA  1677886779
# 10               40        1.14      ID  1677886992

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])

#put into Linear Regression function used earlier
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
LinReg(slope,intercept,rvalue, northern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(0,0),color='red')
# Out:
# The r-value is: -0.887150373715978
# Text(0, 0, 'y = -1.28x + 94.17')

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])

#put into Linear Regression function used earlier
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
LinReg(slope,intercept,rvalue, southern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(-15,55),color='red')
# Out:
# The r-value is: 0.47626050007150533
# Text(-15, 55, 'y = 0.27x + 79.16')

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be a strong negative correlation between latitude and max temp for the northern hemisphere, which is consistent with what we would expect based on our knowledge of the equator. However, there isn't a strong positive correlation between Latitude and Max Temp in the Southern hemisphere. This may be a result of more data being available for the northern hemisphere than the southern hemisphere.

# %%
print(f"The northern hemisphere has {northern_hemi_df['Max Temp'].size} in city_data_df.")
print(f"The southern hemisphere has {southern_hemi_df['Max Temp'].size} in city_data_df.")
# Out:
# The northern hemisphere has 310 in city_data_df.
# The southern hemisphere has 135 in city_data_df.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])

#put into Linear Regression function used earlier
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
LinReg(slope,intercept,rvalue, northern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(60,20),color='red')
# Out:
# The r-value is: 0.3345697394273124
# Text(60, 20, 'y = 0.38x + 57.03')

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])

#put into Linear Regression function used earlier
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
LinReg(slope,intercept,rvalue, southern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(-15,40),color='red')
# Out:
# The r-value is: 0.5050940747384071
# Text(-15, 40, 'y = 0.73x + 90.40')

# %% [markdown]
# **Discussion about the linear relationship:** There doesn't seem to be a strong correlation for the northern or southern hemisphere between humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])

#put into Linear Regression function used earlier
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
LinReg(slope,intercept,rvalue, northern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(60,20),color='red')
# Out:
# The r-value is: 0.35402909566205965
# Text(60, 20, 'y = 0.71x + 27.39')

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])

#put into Linear Regression function used earlier
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
LinReg(slope,intercept,rvalue, southern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(-50,80),color='red')
# Out:
# The r-value is: 0.3931630104172916
# Text(-50, 80, 'y = 1.03x + 84.03')

# %% [markdown]
# **Discussion about the linear relationship:** There doesn't seem to be a strong correlation for the northern or southern hemisphere between cloudiness and latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])

#put into Linear Regression function used earlier
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
LinReg(slope,intercept,rvalue, northern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(60,20),color='red')
# Out:
# The r-value is: 0.03000466669862365
# Text(60, 20, 'y = 0.01x + 8.30')

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])

#put into Linear Regression function used earlier
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
LinReg(slope,intercept,rvalue, southern_hemi_df["Lat"])
plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}",xy=(-40,20),color='red')
# Out:
# The r-value is: -0.20821121559485162
# Text(-40, 20, 'y = -0.09x + 5.55')

# %% [markdown]
# **Discussion about the linear relationship:** Based on the low R-values, there doesn't seem to be a strong correlation for the northern or southern hemisphere between wind speed and latitude.
